# %% [markdown]
# # **Predict Calorie Expenditure**

# %% [markdown]
# ## **Overview**

# %% [markdown]
# Welcome to the 2025 Kaggle Playground Series! We plan to continue in the spirit of previous playgrounds, providing interesting and approachable datasets for our community to practice their machine learning skills, and anticipate a competition each month.

# %% [markdown]
# ## **Problem definition**

# %% [markdown]
# ### **Goal**
#
# Your goal is to predict **how many calories were burned** during a workout.

# %% [markdown]
# ### **Evaluation**
#
# The evaluation metric for this competition is Root Mean Squared Logarithmic Error.

# %% [markdown]
# ### **Submission File**
#
# For each id row in the test set, you must predict the continuous target, Calories. The file should contain a header and have the following format:
# ```
# id,Calories
# 750000,93.2
# 750001,27.42
# 750002,103.8
# etc.
# ```

# %% [markdown]
# ### **Timeline**
#
# - Start Date - May 1, 2025
# - Entry Deadline - Same as the Final Submission Deadline
# - Team Merger Deadline - Same as the Final Submission Deadline
# - Final Submission Deadline - May 31, 2025
#
# All deadlines are at 11:59 PM UTC on the corresponding day unless otherwise noted. The competition organizers reserve the right to update the contest timeline if they deem it necessary.

# %% [markdown]
# ## **About the Tabular Playground Series**
#
# The goal of the Tabular Playground Series is to provide the Kaggle community with a variety of fairly light-weight challenges that can be used to learn and sharpen skills in different aspects of machine learning and data science. The duration of each competition will generally only last a few weeks, and may have longer or shorter durations depending on the challenge. The challenges will generally use fairly light-weight datasets that are synthetically generated from real-world data, and will provide an opportunity to quickly iterate through various model and feature engineering ideas, create visualizations, etc.
#
# ### **Synthetically-Generated Datasets**
#
# Using synthetic data for Playground competitions allows us to strike a balance between having real-world data (with named features) and ensuring test labels are not publicly available. This allows us to host competitions with more interesting datasets than in the past. While there are still challenges with synthetic data generation, the state-of-the-art is much better now than when we started the Tabular Playground Series two years ago, and that goal is to produce datasets that have far fewer artifacts. Please feel free to give us feedback on the datasets for the different competitions so that we can continue to improve!

# %% [markdown]
# ### **Prizes**
#
# - 1st Place - Choice of Kaggle merchandise
# - 2nd Place - Choice of Kaggle merchandise
# - 3rd Place - Choice of Kaggle merchandise
#
# **Please note**: In order to encourage more participation from beginners, Kaggle merchandise will only be awarded once per person in this series. If a person has previously won, we'll skip to the next team.

# %% [markdown]
# ### **Citation**
#
# Walter Reade and Elizabeth Park. Predict Calorie Expenditure. https://kaggle.com/competitions/playground-series-s5e5, 2025. Kaggle.

# %% [markdown]
# ## **Dataset Description**

# %% [markdown]
# The dataset for this competition (both train and test) was generated from a deep learning model trained on the Calories Burnt Prediction dataset. Feature distributions are close to, but not exactly the same, as the original. Feel free to use the original dataset as part of this competition, both to explore differences as well as to see whether incorporating the original in training improves model performance.
#
# **Files**
#
# - train.csv - the training dataset; Calories is the continuous target
# - test.csv - the test dataset; your objective is to predict the Calories for each row
# - sample_submission.csv - a sample submission file in the correct format.

# %% [markdown]
# ## **Metadata**

# %% [markdown]
# #### **Licence**
#
# [MIT](https://www.mit.edu/~amini/LICENSE.md)

# %% [markdown]
# # **Problem Solution**

# %% [markdown]
# ## **Importing necessary libraries**

# %%
# Installing the xgboost library using the 'pip' command.
# %pip install xgboost
# %pip install pandas
# %pip install scikit-learn
# %pip install seaborn

# %%
# Numpy and pandas
import numpy as np
import pandas as pd

# Fro plotting
import matplotlib.pyplot as plt
import seaborn as sns

# To scale the data using z-score
from sklearn.preprocessing import StandardScaler

# To split the dataset into train/test and for tuning
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, KFold

# Algorithms to use
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Import LabelEncoder for encoding crypted identification numbers.
from sklearn.preprocessing import LabelEncoder

# Importing the XGBClassifier from the xgboost library
from xgboost import XGBRegressor
from sklearn.base import clone

# For tuning model hyperparameters with RandomizedSearchCV.
from scipy.stats import uniform, randint

# To do hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# Metrics to evaluate the model
from sklearn.metrics import confusion_matrix, classification_report,recall_score,precision_score, accuracy_score, roc_auc_score, r2_score, mean_squared_error, mean_absolute_error
from sklearn.metrics import mean_squared_log_error

# To suppress scientific notations
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# To ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Loading the dataset**

# %%
# Define paths.
path_input ='./data'
path_output = './working'

# %%
# Define columns.
columns = ('id', 'Sex', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'Calories')
# Upper case constants for column-variables.
for (v, w) in zip(map(str.upper, columns), columns):
    exec("%s = '%s'" % (v, w))
# Read in the data.
train = pd.read_csv(# the train data
    '/'.join([path_input, 'train.csv']),               # Path to input file.
    header = 0,                                        # Header in line 0.
    names = columns,                                   # Column labels defined.
    index_col = ID,                                    # ID column used for index.
    usecols = columns,                                 # Specify colomns to import.
    skipinitialspace=True,                             # Skip space around ends.
    encoding = "ascii",                                # Assume ascii encoding for input data.
)
test = pd.read_csv(# the test data to submit predictions of CALORIES.
    '/'.join([path_input, 'test.csv']),                # Path to input file.
    header = 0,                                        # Header in line 0.
    names = columns[:-1],                              # Column labels defined (but no Calories-column).
    index_col = ID,                                    # ID column used for index.
    usecols = columns[:-1],                            # Specify colomns to import.
    skipinitialspace=True,                             # Skip space around ends.
    encoding = "ascii",                                # Assume ascii encoding for input data.
)

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Look for missing values**

# %%
# Number of rows and columns.
train.shape, test.shape
# Out:
# ((750000, 8), (250000, 7))

# %%
# Are there duplicated rows?
train.duplicated().sum(),train.duplicated().sum()/train.shape[0]*100, test.duplicated().sum(),test.duplicated().sum()/test.shape[0]*100
# Out:
# (2841, 0.3788, 918, 0.36719999999999997)

# %%
# Percentage of nan/missing values.
(train.isna().sum(axis=1)>0).sum()/train.shape[0]*100, (test.isna().sum(axis=1)>0).sum()/test.shape[0]*100
# Out:
# (0.0, 0.0)

# %% [markdown]
# **Observations**
# - No missing data detected.
# - Train data has 750 thousand rows.
# - Test data has 250 thousand rows.
# - Around 0.4% of the rows are duplicates in the train/test data.

# %%
# Look at the first and last rows of the train data.
display(train.head()),display(train.tail());
# Out:
#        Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# id
# 0     male   36 189.000  82.000    26.000     101.000     41.000   150.000
# 1   female   64 163.000  60.000     8.000      85.000     39.700    34.000
# 2   female   51 161.000  64.000     7.000      84.000     39.800    29.000
# 3     male   20 192.000  90.000    25.000     105.000     40.700   140.000
# 4   female   38 166.000  61.000    25.000     102.000     40.600   146.000
#            Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# id
# 749995    male   28 193.000  97.000    30.000     114.000     40.900   230.000
# 749996  female   64 165.000  63.000    18.000      92.000     40.500    96.000
# 749997    male   60 162.000  67.000    29.000     113.000     40.900   221.000
# 749998    male   45 182.000  91.000    17.000     102.000     40.300   109.000
# 749999  female   39 171.000  65.000    19.000      97.000     40.600   103.000

# %%
# Look at the first and last rows of the test data.
display(test.head()),display(test.tail());
# Out:
#            Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# id
# 750000    male   45 177.000  81.000     7.000      87.000     39.800
# 750001    male   26 200.000  97.000    20.000     101.000     40.500
# 750002  female   29 188.000  85.000    16.000     102.000     40.400
# 750003  female   39 172.000  73.000    20.000     107.000     40.600
# 750004  female   30 173.000  67.000    16.000      94.000     40.500
#            Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# id
# 999995  female   56 159.000  62.000     6.000      85.000     39.400
# 999996    male   32 202.000 101.000     3.000      84.000     38.400
# 999997  female   31 164.000  64.000    14.000      98.000     40.100
# 999998  female   62 158.000  61.000    25.000     106.000     40.700
# 999999    male   31 199.000  96.000    15.000      98.000     39.900

# %%
# Information for each data-columns.
train.info(), test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 750000 entries, 0 to 749999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Sex         750000 non-null  object
#  1   Age         750000 non-null  int64
#  2   Height      750000 non-null  float64
#  3   Weight      750000 non-null  float64
#  4   Duration    750000 non-null  float64
#  5   Heart_Rate  750000 non-null  float64
#  6   Body_Temp   750000 non-null  float64
#  7   Calories    750000 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 51.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 750000 to 999999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Sex         250000 non-null  object
#  1   Age         250000 non-null  int64
#  2   Height      250000 non-null  float64
#  3   Weight      250000 non-null  float64
# ...

# %%
display(train.describe(include='all').T), display(test.describe(include='all').T);
# Out:
#                 count unique     top    freq    mean    std     min     25%  \
# Sex            750000      2  female  375721     NaN    NaN     NaN     NaN
# Age        750000.000    NaN     NaN     NaN  41.420 15.175  20.000  28.000
# Height     750000.000    NaN     NaN     NaN 174.698 12.824 126.000 164.000
# Weight     750000.000    NaN     NaN     NaN  75.146 13.983  36.000  63.000
# Duration   750000.000    NaN     NaN     NaN  15.421  8.354   1.000   8.000
# Heart_Rate 750000.000    NaN     NaN     NaN  95.484  9.450  67.000  88.000
# Body_Temp  750000.000    NaN     NaN     NaN  40.036  0.780  37.100  39.600
# Calories   750000.000    NaN     NaN     NaN  88.283 62.395   1.000  34.000
#
#                50%     75%     max
# Sex            NaN     NaN     NaN
# Age         40.000  52.000  79.000
# Height     174.000 185.000 222.000
# Weight      74.000  87.000 132.000
# Duration    15.000  23.000  30.000
# Heart_Rate  95.000 103.000 128.000
# ...

# %% [markdown]
# **Observations**
# - The Sex-column is labelled with male/female and needs to be digitised later.
# - Data values seem to be reasonable - and no strange values detected in the above tables.

# %% [markdown]
# ### **Make Plots**

# %%
def plot_dist(data, x, w=15, h=5, nbins=10, hue=False, title=None, xlabel=None, ylabel=None):
    fig, (axsU, axsL) = plt.subplots(2, 1, figsize=(w,h), sharex=True)
    skew = f"(skew = {data[x].skew():#,.2g}".removesuffix(".") + ")"
    # Add title
    if (title):
        fig.suptitle(f"{title} {skew}")
    else:
        fig.suptitle(f"Distribution of {data[x].name} {skew}")
    sns.histplot(data=data, x=x, ax=axsL, kde=False, bins=nbins, hue=hue, legend=bool(hue))
    legL = axsL.get_legend() # capture the legend.
    sns.boxplot(data=data, x=x, ax=axsU, hue=hue, legend=bool(hue))
    if hue: axsU.legend(loc="upper left", bbox_to_anchor=(1,1), title="Sex", fontsize='small') 
    # Calculate mean and median and add them as labels.
    q25, median, q75, mean = (data[x].quantile(0.25), data[x].median(), data[x].quantile(0.75), data[x].mean())
    l1, l2, l3, l4 = (
        f"Q1 ({q25:#,.3g}".removesuffix(".") + ")", 
        f"Median ({median:#,.3g}".removesuffix(".") + ")",
        f"Mean ({mean:#,.3g}".removesuffix(".") + ")",
        f"Q4 ({q75:#,.3g}".removesuffix(".") + ")"
    )
    q1, q2, q3, q4 = (
        plt.axvline(q25, color='yellow', label=l1),
        plt.axvline(median, color='red', label=l2),
        plt.axvline(mean, color='green', label=l3),
        plt.axvline(q75, color='yellow', label=l4)
    )
    axsL.legend(handles=[q1, q2, q3, q4], loc='upper left', bbox_to_anchor=(1, 1), fontsize='medium', frameon=False, title="Quantiles")
    if hue: axsL.add_artist(legL) # It is necessary to add this legend back.
    # Add labels on axes.
    if (xlabel): plt.xlabel(xlabel) 
    if (ylabel): plt.ylabel(ylabel)
    plt.show()
# Make some distributions plots - and distinguish between female/male.
for COL in columns[2:-1]:
    plot_dist(data=train, x=COL, hue=SEX, title=f"train, {COL}")
    plot_dist(data=test, x=COL, hue=SEX, title=f"test, {COL}")
plot_dist(data=train, x=CALORIES, hue=SEX, title=f"train, {CALORIES}") # Only train data has CALORIES column.

# %%
# Some more plots for looking at connection between variable on a scatter plot.
# First some definitions.
sns.set(rc={"figure.figsize": (10, 4)}) # Size of figure.
plegend = {'loc':'upper left', 'bbox_to_anchor':(1, 1), 'fontsize':'medium', 'title':"Sex"} # How to adjust legend.

# %%
# Height vs Weight
sns.scatterplot(data=train, x=HEIGHT, y=WEIGHT, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Heart Rate vs Age
sns.scatterplot(data=train, x=AGE, y=HEART_RATE, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Heart Rate vs Body Temperature
sns.scatterplot(data=train, x=BODY_TEMP, y=HEART_RATE, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Duration vs Age
sns.scatterplot(data=train, x=AGE, y=DURATION, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();

# %%
# Calories vs AGE
sns.scatterplot(data=train, x=AGE, y=CALORIES, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories vs HEIGHT
sns.scatterplot(data=train, x=HEIGHT, y=CALORIES, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories vs Weight
sns.scatterplot(data=train, x=WEIGHT, y=CALORIES, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories vs Duration
sns.scatterplot(data=train, x=DURATION, y=CALORIES, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories vs Heart Rate
sns.scatterplot(data=train, x=HEART_RATE, y=CALORIES, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories vs Body Temperature
sns.scatterplot(data=train, x=BODY_TEMP, y=CALORIES, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();

# %%
# Calories vs Body Temperature
LC = 'log_calories'
CPM = 'calories_per_minute'
train = train.assign(**{
    LC: lambda x: np.log1p(x[CALORIES]), # log1p(x) = ln(1+x)
    CPM: lambda x: np.log1p(x[CALORIES] / x[DURATION]) # log1p(x) = ln(1+x)
})

# %%
train.head()
# Out:
#        Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# id
# 0     male   36 189.000  82.000    26.000     101.000     41.000   150.000
# 1   female   64 163.000  60.000     8.000      85.000     39.700    34.000
# 2   female   51 161.000  64.000     7.000      84.000     39.800    29.000
# 3     male   20 192.000  90.000    25.000     105.000     40.700   140.000
# 4   female   38 166.000  61.000    25.000     102.000     40.600   146.000
#
#     log_calories  calories_per_minute
# id
# 0          5.017                1.912
# 1          3.555                1.658
# 2          3.401                1.638
# 3          4.949                1.887
# 4          4.990                1.923

# %%
# Calories per duration vs AGE
sns.scatterplot(data=train, x=AGE, y=CPM, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories per duration vs HEIGHT
sns.scatterplot(data=train, x=HEIGHT, y=CPM, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories per duration vs Weight
sns.scatterplot(data=train, x=WEIGHT, y=CPM, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories per duration vs Duration
sns.scatterplot(data=train, x=DURATION, y=CPM, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories per duration vs Heart Rate
sns.scatterplot(data=train, x=HEART_RATE, y=CPM, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();
# Calories per duration vs Body Temperature
sns.scatterplot(data=train, x=BODY_TEMP, y=CPM, alpha=0.5, hue=SEX);plt.legend(**plegend);plt.show();

# %% [markdown]
# ## **Modelling**

# %% [markdown]
# ### **Digitising**

# %%
# Make a copy of data.
train_df = train.copy()
test_df = test.copy()

# %%
# Leta male be 0 and female be 1.
rplc={'male': 0, 'female': 1}
train_df.replace(rplc, inplace=True), test_df.replace(rplc, inplace=True)
# Out:
# (None, None)

# %%
display(train_df.head()),display(test_df.head());
# Out:
#     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# id
# 0     0   36 189.000  82.000    26.000     101.000     41.000   150.000
# 1     1   64 163.000  60.000     8.000      85.000     39.700    34.000
# 2     1   51 161.000  64.000     7.000      84.000     39.800    29.000
# 3     0   20 192.000  90.000    25.000     105.000     40.700   140.000
# 4     1   38 166.000  61.000    25.000     102.000     40.600   146.000
#
#     log_calories  calories_per_minute
# id
# 0          5.017                1.912
# 1          3.555                1.658
# 2          3.401                1.638
# 3          4.949                1.887
# 4          4.990                1.923
#         Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# id
# 750000    0   45 177.000  81.000     7.000      87.000     39.800
# 750001    0   26 200.000  97.000    20.000     101.000     40.500
# 750002    1   29 188.000  85.000    16.000     102.000     40.400
# ...

# %% [markdown]
# ### **Feature Engineering**

# %%
# Brainstorm!
# New data columns:
BMI1 = 'bmi_height_first_order'  # Body mass index 1
BMI2 = 'bmi_height_second_order' # Body mass index 2 (normal)
BMI3 = 'bmi_height_third_order'  # Body mass index 3
WA1  = 'weight_age_first_order'  # Weight age index 1
WA2  = 'weight_age_second_order' # Weight age index 2
WA3  = 'weight_age_third_order'  # Weight age index 3
BMR = 'basal_metabolic_rate'     # BMR
AGB = 'age_groups'               # Age groups
SAGB = 'sex_age_groups'          # Sex-age groups
HRD = 'heart_rate_duration'      # Heart rate times duration
BTD = 'body_temp_duration'       # Body temperature times duration
AGR = 'age_groups'               # Age groups
BTH = 'body_temp_heart_rate'     # Body temperature times heart rate
HRA = 'heart_rate_per_age'       # Heart rate per age
LGW = 'log_of_weight'            # Log(Weight)
SRH = 'square_root_of_height'    # sqrt(Height)
AG2 = 'age_squared'              # Age**2
WG3 = 'weight_cubed'             # Weight**3
BTDS = 'body_temp_on_duration_squared' # Body temperature times duration squared
HRDS = 'heart_rate_on_duration_squared' # Heart rate times duration squared
HGDS = 'height_on_duration_squared' # Height times duration squared
LGD = 'log_of_duration'          # Log of duration
SRD = 'square_root_of_duration'  # Square root of duration
DRW = 'duration_over_weight'     # Duration over weight
DRH = 'duration_over_height'     # Duration over height
HRDB = 'heart_rate_duration_body_temp' # Heart rate times duration times body temperature
HRDH = 'heart_rate_duration_height' # Heart rate times duration times height
HRDH = 'heart_rate_duration_height' # Heart rate times duration times height
BDH = 'body_temp_duration_height' # Body temperature times duration times height
CB = 'calories_calculated'       # Calculated Calories
HRGM = 'heart_rate_about_mean_by_sex' # Heart rate about mean  by sex
HRMS = 'heart_rate_mean_by_sex_squared' # Heart rate mean  by sex squared
HRMD = 'heart_rate_mean_by_sex_duration' # Heart rate mean  by sex times duration
HRMB = 'heart_rate_mean_by_sex_body_temp' # Heart rate mean  by sex times body temperature
SGD = 'age_sex_duration'         # Age-sex times duration
SGH = 'age_sex_heart_rate'       # Age-sex times heart rate
SGB = 'age_sex_body_temp'        # Age-sex times body temperature

def derived_features(df):
    """
    Create new features based on meteorological understanding and data analysis.
    Ensures no data leakage by avoiding use of the target variable (CALORIES).
    """
    group_stats = df.groupby(SEX)[HEART_RATE].agg(['mean', 'std']).rename(columns={'mean': 'Mean_HR_by_Sex', 'std': 'Std_HR_by_Sex'})
    
    # Return amended dataframe.
    features = df.assign(**{
      BMI1: lambda x: x[WEIGHT] / (x[HEIGHT]/100),
      BMI2: lambda x: x[WEIGHT] / (x[HEIGHT]/100)**2,
      BMI3: lambda x: x[WEIGHT] / (x[HEIGHT]/100)**3,
      WA1: lambda x: x[WEIGHT] / x[AGE],
      WA2: lambda x: x[WEIGHT] / x[AGE]**2,
      WA3: lambda x: x[WEIGHT] / x[AGE]**3,
      BMR: lambda x: 10*x[WEIGHT] + 6.25*x[HEIGHT] - 5*x[AGE] - 161*x[SEX] - 5*(x[SEX] - 1),
      AGB: lambda x: pd.cut(x[WEIGHT], bins=[0, 50, 60, 70, 80, 90, 100, 110, 999], labels=[0, 1, 2, 3, 4, 5, 6, 7, 8]),
      SAGB: lambda x: LabelEncoder().fit_transform(x[SEX].astype(str) + x[AGE].astype(str)),
      # Taken from https://www.kaggle.com/competitions/playground-series-s5e5/discussion/575843
      HRD: lambda x: x[HEART_RATE] * x[DURATION],
      BTD: lambda x: x[BODY_TEMP] * x[DURATION],
      AGR: lambda x: pd.cut(x[AGE], bins=[0, 20, 35, 50, 100], labels=[0, 1, 2, 3]),
      # Taken from https://www.kaggle.com/code/cristobaltudela/xgboost-predict-calorie-ps-s5e5
      BTH: lambda x: x[BODY_TEMP] * x[HEART_RATE],
      HRA: lambda x: x[HEART_RATE] / x[AGE],
      LGW: lambda x: np.log1p(x[WEIGHT]),
      SRH: lambda x: np.sqrt(x[HEIGHT]),
      AG2: lambda x: x[AGE]**2,
      WG3: lambda x: x[WEIGHT]**3,
      BTDS: lambda x: x[BODY_TEMP] * x[DURATION]**2,
      HRDS: lambda x: x[HEART_RATE] * x[DURATION]**2,
      HGDS: lambda x: x[HEIGHT] * x[DURATION]**2,
      LGD: lambda x: np.log1p(x[DURATION]),
      DRW: lambda x: x[DURATION] / x[WEIGHT],      
      DRH: lambda x: x[DURATION] / x[HEIGHT],      
      HRDB: lambda x: x[HEART_RATE] * x[DURATION] * x[BODY_TEMP],      
      HRDH: lambda x: x[HEART_RATE] * x[DURATION] * x[HEIGHT],      
      BDH: lambda x: x[BODY_TEMP] * x[DURATION] * x[HEIGHT],    
      # From https://www.omnicalculator.com/sports/calories-burned-by-heart-rate
      # Weights from Sayuri (weight for women 1.27, weight for men 0.69)
      CB: lambda x: (
        (0.4472*x[HEART_RATE] - 0.1263*x[WEIGHT] + 0.0740*x[AGE] - 20.4022) *      x[SEX]  * 1.27   # women
          +
        (0.6309*x[HEART_RATE] + 0.1988*x[WEIGHT] + 0.2017*x[AGE] - 55.0969) * (1 - x[SEX]) * 0.69   # men
      ) * x[DURATION] / 4.184,
     HRGM: lambda x: x[HEART_RATE] - x.groupby(SEX, as_index=False, sort=False)[HEART_RATE].transform('mean'),
     HRMS: lambda x: (x.groupby(SEX, as_index=False, sort=False)[HEART_RATE].transform('mean'))**2,
     HRMD: lambda x: x.groupby(SEX, as_index=False, sort=False)[HEART_RATE].transform('mean') * x[DURATION],
     HRMB: lambda x: x.groupby(SEX, as_index=False, sort=False)[HEART_RATE].transform('mean') * x[BODY_TEMP],
     SGD: lambda x: x[SAGB] * x[DURATION],
     SGH: lambda x: x[SAGB] * x[HEART_RATE],
     SGB: lambda x: x[SAGB] * x[BODY_TEMP],
    })
    # Interacciones entre variables
    #col = [AGE, WEIGHT, HEIGHT, BODY_TEMP, HEART_RATE, DURATION, SEX, SAGB]
    #for comb in itertools.combinations(col, 2):
    #    features['_'.join(comb)] = features[list(comb)].prod(axis=1)
    return features

train_df = derived_features(train_df)
test_df = derived_features(test_df)

# %%
# We do not need many identical rows (but we keep all rows of test, as that is used forhttps://ca.slack-edge.com/T075K68NW4S-U07MMFU4XMX-40a13bd90b50-512 scoring).
train_df.drop_duplicates(inplace=True)

# %%
train_df[SAGB]
# Out:
# id
# 0          16
# 1         104
# 2          91
# 3           0
# 4          78
#          ...
# 749995      8
# 749996    104
# 749997     40
# 749998     25
# 749999     79
# Name: sex_age_groups, Length: 747159, dtype: int64

# %%
train_df[[AGE, SEX, CALORIES, CB]]
# Out:
#         Age  Sex  Calories  calories_calculated
# id
# 0        36    0   150.000              138.009
# 1        64    1    34.000               35.861
# 2        51    1    29.000               27.310
# 3        20    0   140.000              136.357
# 4        38    1   146.000              154.196
# ...     ...  ...       ...                  ...
# 749995   28    0   230.000              206.589
# 749996   64    1    96.000               95.720
# 749997   60    0   221.000              199.031
# 749998   45    0   109.000              102.111
# 749999   39    1   103.000              101.807
#
# [747159 rows x 4 columns]

# %%
train_df.head()
# Out:
#     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# id
# 0     0   36 189.000  82.000    26.000     101.000     41.000   150.000
# 1     1   64 163.000  60.000     8.000      85.000     39.700    34.000
# 2     1   51 161.000  64.000     7.000      84.000     39.800    29.000
# 3     0   20 192.000  90.000    25.000     105.000     40.700   140.000
# 4     1   38 166.000  61.000    25.000     102.000     40.600   146.000
#
#     log_calories  calories_per_minute  ...  heart_rate_duration_height  \
# id                                     ...
# 0          5.017                1.912  ...                  496314.000
# 1          3.555                1.658  ...                  110840.000
# 2          3.401                1.638  ...                   94668.000
# 3          4.949                1.887  ...                  504000.000
# 4          4.990                1.923  ...                  423300.000
#
#     body_temp_duration_height  calories_calculated  \
# ...

# %% [markdown]
# ### **Scaling data**

# %%
NUM_COLUMNS = train_df.columns.to_list()
SCALED_COLUMNS = [x for x in NUM_COLUMNS if x not in [CALORIES, LC, CPM]]

sc = StandardScaler()

train_scaled = train_df.copy()
test_scaled = test_df.copy()

train_scaled[SCALED_COLUMNS] = sc.fit_transform(train_df[SCALED_COLUMNS])
test_scaled[SCALED_COLUMNS]  = sc.transform(test_df[SCALED_COLUMNS])

# %%
train_scaled.head().T, test_scaled.head().T
# Out:
# (id                                     0      1      2       3       4
#  Sex                               -1.002  0.998  0.998  -1.002   0.998
#  Age                               -0.357  1.487  0.631  -1.411  -0.225
#  Height                             1.116 -0.912 -1.068   1.350  -0.678
#  Weight                             0.491 -1.083 -0.797   1.063  -1.012
#  Duration                           1.265 -0.890 -1.010   1.145   1.145
#  Heart_Rate                         0.582 -1.111 -1.216   1.006   0.688
#  Body_Temp                          1.235 -0.433 -0.305   0.850   0.722
#  Calories                         150.000 34.000 29.000 140.000 146.000
#  log_calories                       5.017  3.555  3.401   4.949   4.990
#  calories_per_minute                1.912  1.658  1.638   1.887   1.923
#  bmi_height_first_order             0.140 -1.165 -0.581   0.832  -1.178
#  bmi_height_second_order           -0.938 -1.185  0.209   0.026  -1.480
# ...

# %% [markdown]
# ### **Covariance Matrix**

# %%
plt.figure(figsize  = (20, 20))
corr = train_scaled[NUM_COLUMNS].corr()
sns.heatmap(corr, annot = False, vmin=-1, vmax=1, cmap = "PiYG")
plt.show()

corr[CALORIES].sort_values(key=lambda col: -abs(col))
# Out:
# Calories                            1.000
# calories_calculated                 0.989
# heart_rate_duration_body_temp       0.978
# heart_rate_duration                 0.977
# heart_rate_duration_height          0.973
# heart_rate_on_duration_squared      0.969
# body_temp_on_duration_squared       0.965
# height_on_duration_squared          0.964
# body_temp_duration                  0.961
# heart_rate_mean_by_sex_duration     0.960
# Duration                            0.960
# body_temp_duration_height           0.956
# duration_over_height                0.943
# body_temp_heart_rate                0.925
# Heart_Rate                          0.909
# heart_rate_about_mean_by_sex        0.909
# log_calories                        0.902
# duration_over_weight                0.876
# log_of_duration                     0.873
# calories_per_minute                 0.844
# heart_rate_mean_by_sex_body_temp    0.829
# Body_Temp                           0.829
# ...

# %% [markdown]
# ### **Split data for modelling and validation sets**

# %%
# Dividing train data into X (input data matrix) and y (output vector)
X = train_scaled.drop([CALORIES,LC,CPM], axis=1)
y = train_scaled[CALORIES]
y_lc = train_scaled[LC]
y_cpm = train_scaled[CPM]

# %%
train.loc[train[DURATION]<=1,DURATION]
# Out:
# id
# 17       1.000
# 40       1.000
# 66       1.000
# 141      1.000
# 146      1.000
#           ...
# 749653   1.000
# 749655   1.000
# 749740   1.000
# 749914   1.000
# 749967   1.000
# Name: Duration, Length: 12648, dtype: float64

# %%
# Splitting data into training and validation set:
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=1)
X_lc_train, X_lc_val, y_lc_train, y_lc_val = train_test_split(X, y_lc, test_size=0.3, random_state=1)
X_cpm_train, X_cpm_val, y_cpm_train, y_cpm_val = train_test_split(X, y_cpm, test_size=0.3, random_state=1)

display(X_train.shape, X_val.shape)
display(X_lc_train.shape, X_lc_val.shape)
display(X_cpm_train.shape, X_cpm_val.shape)
# Out:
# (523011, 41)
# (224148, 41)
# (523011, 41)
# (224148, 41)
# (523011, 41)
# (224148, 41)

# %% [markdown]
# ### **Metric Functions**

# %%
# Function to compute adjusted R-squared
def adj_r2_score(predictors, targets, predictions):
    r2 = r2_score(targets, predictions)
    n = predictors.shape[0]
    k = predictors.shape[1]
    return 1 - ((1 - r2) * (n - 1) / (n - k - 1))


# Function to compute different metrics to check performance of a regression model
def model_performance_regression(model, predictors, target):
    """
    Function to compute different metrics to check regression model performance

    model: regressor
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    r2 = r2_score(target, pred)  # to compute R-squared
    adjr2 = adj_r2_score(predictors, target, pred)  # to compute adjusted R-squared
    rmse = np.sqrt(mean_squared_error(target, pred))  # to compute RMSE
    rmsle = np.sqrt(mean_squared_log_error (target, pred)) # to compute RMSLE
    mae = mean_absolute_error(target, pred)  # to compute MAE

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "RMSLE": rmsle,
            "RMSE": rmse,
            "MAE": mae,
            "R-squared": r2,
            "Adj. R-squared": adjr2,
        },
        index=[0],
    )

    return df_perf

# %% [markdown]
# ### **Models**

# %% [markdown]
# #### **Overfitted models**

# %%
dtree = DecisionTreeClassifier(random_state=1)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
dtree_model_train_perf = model_performance_regression(dtree, X_train, y_train)
dtree_model_train_perf
# Out:
#    RMSLE  RMSE   MAE  R-squared  Adj. R-squared
# 0  0.005 0.269 0.013      1.000           1.000

# %%
rf_estimator = RandomForestClassifier(random_state=1)
rf_estimator.fit(X_train[:100000], y_train[:100000])
# Out:
# RandomForestClassifier(random_state=1)

# %%
rf_estimator_model_train_perf = model_performance_regression(
    rf_estimator, X_train[:100000], y_train[:100000]
)
rf_estimator_model_train_perf
# Out:
#    RMSLE  RMSE   MAE  R-squared  Adj. R-squared
# 0  0.002 0.103 0.003      1.000           1.000

# %% [markdown]
# #### **Model candidate**

# %%
xgb_lc_estimator = XGBRegressor(random_state=1)
xgb_lc_estimator.fit(X_lc_train, y_lc_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_cpm_estimator = XGBRegressor(random_state=1)
xgb_cpm_estimator.fit(X_cpm_train, y_cpm_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_lc_estimator_model_train_perf = model_performance_regression(
    xgb_lc_estimator, X_lc_train, y_lc_train
)
xgb_lc_estimator_model_train_perf
# Out:
#    RMSLE  RMSE   MAE  R-squared  Adj. R-squared
# 0  0.016 0.056 0.034      0.997           0.997

# %%
xgb_cpm_estimator_model_train_perf = model_performance_regression(
    xgb_cpm_estimator, X_cpm_train, y_cpm_train
)
xgb_cpm_estimator_model_train_perf
# Out:
#    RMSLE  RMSE   MAE  R-squared  Adj. R-squared
# 0  0.019 0.047 0.029      0.962           0.962

# %%
# Training performance comparison
models_train_comp_df = pd.concat(
    [
        dtree_model_train_perf.T,
        rf_estimator_model_train_perf.T,
        xgb_lc_estimator_model_train_perf.T,
        xgb_cpm_estimator_model_train_perf.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Decision Tree",
    "Random Forest",
    "Xgboost Log CALORIES",
    "Xgboost CPM",
]
print("Training performance comparison:")
models_train_comp_df.T
# Out:
# Training performance comparison:
#                       RMSLE  RMSE   MAE  R-squared  Adj. R-squared
# Decision Tree         0.005 0.269 0.013      1.000           1.000
# Random Forest         0.002 0.103 0.003      1.000           1.000
# Xgboost Log CALORIES  0.016 0.056 0.034      0.997           0.997
# Xgboost CPM           0.019 0.047 0.029      0.962           0.962

# %% [markdown]
# ## **Tuning Models**

# %%
# Tuning Xgboost!
# randint(low,high) => {low,high-1}
# uniform(loc,scale) => [loc, loc + scale]
# Setting up parameter grid to tune the hyperparameters.
param_distributions = {
    'learning_rate': uniform(0,0.5),                                   # Boosting learning rate (xgb’s “eta”).
    'n_estimators': randint(1,201),                                    # Number of gradient boosted trees. Equivalent to number of boosting rounds.
    'max_depth': randint(1,25),                                        # Maximum tree depth for base learners.
    'random_state': [1],                                               # For setting random state for prediction algorithm.
}
# Performing 3-fold cross-validation to tune the hyperparameters.
xgb_search = RandomizedSearchCV(
    estimator=XGBRegressor(random_state=1),
    param_distributions=param_distributions,
    n_iter=2,
    #refit="r2",
    #scoring=["r2"],
    cv=3,
    n_jobs=-1,
    #pre_dispatch=8,

)

# Fitting the data.
xgb_search.fit(X_train, y_train)

# Best score (estimator’s score method is used if scoring and refit parameters are not set).
print(xgb_search.best_score_)

# Combination of parameters that gave the best score.
print(xgb_search.best_params_)
#0.9965680415699621
#{'learning_rate': 0.03689019702704138, 'max_depth': 9, 'n_estimators': 163, 'random_state': 1}
# Out:
# 0.9954305516481604
# {'learning_rate': 0.46398979378575983, 'max_depth': 21, 'n_estimators': 172, 'random_state': 1}

# %%
# Tuning Xgboost!
# randint(low,high) => {low,high-1}
# uniform(loc,scale) => [loc, loc + scale]
# Setting up parameter grid to tune the hyperparameters.
param_distributions = {
    'learning_rate': uniform(0,1),                                 # Boosting learning rate (xgb’s “eta”).
    'n_estimators': randint(1,251),                                  # Number of gradient boosted trees. Equivalent to number of boosting rounds.
    'max_depth': randint(1,51),                                      # Maximum tree depth for base learners.
    'random_state': [1],                                             # For setting random state for prediction algorithm.
}
# Performing 3-fold cross-validation to tune the hyperparameters.
xgb_lc_search = RandomizedSearchCV(
    estimator=XGBRegressor(random_state=1),
    param_distributions=param_distributions,
    n_iter=20,
    #refit="r2",
    #scoring=["r2"],
    cv=3,
    n_jobs=-1,
    #pre_dispatch=8,

)

# Fitting the data.
xgb_lc_search.fit(X_lc_train, y_lc_train)

# Best score (estimator’s score method is used if scoring and refit parameters are not set).
print(xgb_lc_search.best_score_)

# Combination of parameters that gave the best score.
print(xgb_lc_search.best_params_)
#0.9950210593918315
#{'learning_rate': 0.2773300394776438, 'max_depth': 42, 'n_estimators': 59, 'random_state': 1}
#0.9950567837664687
#{'learning_rate': 0.27220105506849757, 'max_depth': 33, 'n_estimators': 142, 'random_state': 1}
# Out:
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# Cell In[30], line 25
#      12 xgb_lc_search = RandomizedSearchCV(
#      13     estimator=XGBRegressor(random_state=1),
#      14     param_distributions=param_distributions,
#    (...)     21
#      22 )
#      24 # Fitting the data.
# ---> 25 xgb_lc_search.fit(X_lc_train, y_lc_train)
#      27 # Best score (estimator’s score method is used if scoring and refit parameters are not set).
#      28 print(xgb_lc_search.best_score_)
#
# File ~/.local/share/virtualenvs/Jupyter-1lo4x-w-/lib64/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# ...

# %%
# Tuning Xgboost!
# randint(low,high) => {low,high-1}
# uniform(loc,scale) => [loc, loc + scale]
# Setting up parameter grid to tune the hyperparameters.
param_distributions = {
    'learning_rate': uniform(0,0.5),                                   # Boosting learning rate (xgb’s “eta”).
    'n_estimators': randint(1,201),                                    # Number of gradient boosted trees. Equivalent to number of boosting rounds.
    'max_depth': randint(1,25),                                        # Maximum tree depth for base learners.
    'random_state': [1],                                               # For setting random state for prediction algorithm.
}
# Performing 3-fold cross-validation to tune the hyperparameters.
xgb_cpm_search = RandomizedSearchCV(
    estimator=XGBRegressor(random_state=1),
    param_distributions=param_distributions,
    n_iter=2,
    #refit="r2",
    #scoring=["r2"],
    cv=3,
    n_jobs=-1,
    #pre_dispatch=8,

)

# Fitting the data.
xgb_cpm_search.fit(X_cpm_train, y_cpm_train)

# Best score (estimator’s score method is used if scoring and refit parameters are not set).
print(xgb_cpm_search.best_score_)

# Combination of parameters that gave the best score.
print(xgb_cpm_search.best_params_)

# %%
bp = {'learning_rate': 0.03689019702704138, 'max_depth': 9, 'n_estimators': 163, 'random_state': 1}
xgb_estimator = XGBRegressor(**bp)
xgb_estimator.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03689019702704138, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=163, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
lc_bp = {'learning_rate': 0.03689019702704138, 'max_depth': 9, 'n_estimators': 163, 'random_state': 1}
xgb_lc_estimator = XGBRegressor(**lc_bp)
xgb_lc_estimator.fit(X_lc_train, y_lc_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03689019702704138, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=163, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
cpm_bp = {'learning_rate': 0.03689019702704138, 'max_depth': 9, 'n_estimators': 163, 'random_state': 1}
xgb_cpm_estimator = XGBRegressor(**cpm_bp)
xgb_cpm_estimator.fit(X_cpm_train, y_cpm_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03689019702704138, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=163, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
xgb_prediction = xgb_estimator.predict(test_scaled)
xgb_lc_prediction = xgb_lc_estimator.predict(test_scaled)
xgb_cpm_prediction = xgb_cpm_estimator.predict(test_scaled)

# %%
xgb_prediction.round(3),xgb_lc_prediction.round(3),xgb_cpm_prediction.round(3)
# Out:
# (array([ 27.925, 107.215,  86.577, ...,  72.71 , 168.444,  76.435],
#        dtype=float32),
#  array([3.363, 4.683, 4.462, ..., 4.298, 5.129, 4.347], dtype=float32),
#  array([1.581, 1.861, 1.867, ..., 1.816, 2.045, 1.813], dtype=float32))

# %%
submission = pd.Series(
  data = xgb_prediction.round(3),
  index = test_scaled.index,
  name = CALORIES
)
# Model np.log1p(calories) -> therefore backtransform here to get calories.
lc_submission = pd.Series(
  data = np.expm1(xgb_lc_prediction).round(3),
  index = test.index,
  name = CALORIES
)
# Model np.log1p(calories / duration) -> therefore backtransform here to get calories.
cpm_submission = pd.Series(
  data = (np.expm1(xgb_cpm_prediction) * test[DURATION]).round(3),
  index = test.index,
  name = CALORIES
)

# %%
display(submission.loc[submission < 0])
submission.loc[submission < 0 ] = 0
display(submission.loc[submission <= 0])
# Out:
# Series([], Name: Calories, dtype: float32)
# Series([], Name: Calories, dtype: float32)

# %%
display(lc_submission.loc[lc_submission < 0])
lc_submission.loc[lc_submission < 0 ] = 0
display(lc_submission.loc[lc_submission <= 0])
# Out:
# Series([], Name: Calories, dtype: float32)
# Series([], Name: Calories, dtype: float32)

# %%
display(cpm_submission.loc[cpm_submission < 0])
cpm_submission.loc[cpm_submission < 0 ] = 0
display(cpm_submission.loc[cpm_submission <= 0])
# Out:
# Series([], Name: Calories, dtype: float64)
# Series([], Name: Calories, dtype: float64)

# %%
submission.to_csv('/'.join([path_output, 'submission.csv']))
lc_submission.to_csv('/'.join([path_output, 'lc_submission.csv']))
cpm_submission.to_csv('/'.join([path_output, 'cpm_submission.csv']))
